# %% [markdown]
# # **Imports**

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import  confusion_matrix, classification_report , accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.dummy import DummyClassifier

# %%
df = pd.read_csv(r'data\framingham.csv')
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %% [markdown]
# # **Eplore the data**

# %%
df.shape
# Out:
# (4238, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# min       0.000000         0.000000      0.000000     0.000000   107.000000
# 25%       0.000000         0.000000      0.000000     0.000000   206.000000
# 50%       0.000000         0.000000      0.000000     0.000000   234.000000
# 75%       0.000000         0.000000      1.000000     0.000000   263.000000
# max       1.000000         1.000000      1.000000     1.000000   696.000000
#
#              sysBP        diaBP          BMI    heartRate      glucose  \
# count  4238.000000  4238.000000  4219.000000  4237.000000  3850.000000
# mean    132.352407    82.893464    25.802008    75.878924    81.966753
# std      22.038097    11.910850     4.080111    12.026596    23.959998
# min      83.500000    48.000000    15.540000    44.000000    40.000000
# 25%     117.000000    75.000000    23.070000    68.000000    71.000000
# 50%     128.000000    82.000000    25.400000    75.000000    78.000000
# 75%     144.000000    89.875000    28.040000    83.000000    87.000000
# max     295.000000   142.500000    56.800000   143.000000   394.000000
#
#         TenYearCHD
# count  4238.000000
# mean      0.151958
# std       0.359023
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# # # **Data Preprocessing**

# %% [markdown]
# # **Calculate missing values**

# %%
df.drop(columns = 'education', inplace = True)

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# glucose            388
# BPMeds              53
# totChol             50
# cigsPerDay          29
# BMI                 19
# heartRate            1
# male                 0
# age                  0
# currentSmoker        0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# sysBP                0
# diaBP                0
# TenYearCHD           0
# dtype: int64

# %%
#filled missing values in 'cigsPerDay' column with 0
df['cigsPerDay'].fillna(value=0.0,inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_5352\1715309715.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cigsPerDay'].fillna(value=0.0,inplace=True)

# %% [markdown]
#  >  **we will fill other null values in the pipeline**

# %% [markdown]
# # **Data distribution**

# %% [markdown]
# **Plot the distribution for all features.**

# %%
df.hist(figsize=(16, 20), bins=40, xlabelsize=13, ylabelsize=7);

# %% [markdown]
# # **Outliers**

# %%
plt.figure(figsize=(20,20))
for idx,column in enumerate(df):
    plt.subplot(4,4,idx+1)
    sns.boxplot(x='TenYearCHD' , y= column , data=df)
    plt.xlabel('TenYearCHD')
    plt.ylabel(column)
    plt.title(f"{column} Distribution")
plt.show()

# %% [markdown]
# **There is not a lot of outliers**

# %% [markdown]
# # **Multicollinearity**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = df.corr(numeric_only=True)
mask = (corr < 0.5) & (corr > -0.5)
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='Greens', mask=mask)
plt.show()

# %% [markdown]
# # **Splitting data for train and test**

# %%
X = df.drop(columns=['TenYearCHD'])
target = df['TenYearCHD']

X_train , X_test , y_train , y_test = train_test_split(X ,target ,test_size=0.2 , random_state=42 )
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (3390, 14)
# y_train shape: (3390,)
# X_test shape: (848, 14)
# y_test shape: (848,)

# %% [markdown]
# # **Baseline**

# %% [markdown]
# - Sets Performance Expectations: Baseline models provide a clear benchmark, helping businesses set realistic goals for advanced models.
# - Evaluates Model Value: By comparing complex models against a baseline, businesses can decide if added complexity is truly beneficial.
# - Guides Model Development: Baseline models reveal initial data insights and feature relationships, helping inform further model design decisions.

# %%
dummy_classifier = DummyClassifier(strategy = 'most_frequent')
dummy_classifier.fit(X_train, y_train)
y_pred = dummy_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Baseline Model Accuracy: {accuracy:.4f}")
# Out:
# Baseline Model Accuracy: 0.8538

# %% [markdown]
# # **Logistic regression model**

# %%
LR_model = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    LogisticRegression()
)
LR_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
# get predictions for training and testing data
y_training_pred = LR_model.predict(X_train)
y_testing_pred = LR_model.predict(X_test)

#get accuracy for training and testing
training_acc = accuracy_score(y_train, y_training_pred)
testing_acc = accuracy_score(y_test, y_testing_pred)

print(f"Training accuracy : {training_acc: .4f}")
print(f"Testing accuracy : {testing_acc: .4f}")
# Out:
# Training accuracy :  0.8546
# Testing accuracy :  0.8573

# %% [markdown]
# # **Confusion matrix**

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cm,annot=True,cmap="Blues",xticklabels=["Predictied Negative","Predicted Positive"],
            yticklabels=["Actual Negative","Actual Positive"],fmt="d")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
print(classification_report(y_test , LR_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       724
#            1       0.60      0.07      0.13       124
#
#     accuracy                           0.86       848
#    macro avg       0.73      0.53      0.53       848
# weighted avg       0.82      0.86      0.81       848

# %%
round((0.92+0.13)/2,2)
# Out:
# 0.53

# %% [markdown]
# # AUC-ROC curve

# %%
y_prob = LR_model.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

auc = roc_auc_score(y_test, y_prob)

plt.plot(fpr, tpr, label="ROC Curve (AUC = {:.2f})".format(auc))

plt.plot([0, 1], [0, 1], linestyle='--', label="Random Classifier")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("ROC Curve for Logistic Regression")
plt.legend()
plt.show()

# %%
# Print FPR, TPR, and Thresholds
for f, t, thr in zip(fpr, tpr, thresholds):
    print(f"Threshold: {thr:.2f}, FPR: {f:.2f}, TPR: {t:.2f}")
# Out:
# Threshold: inf, FPR: 0.00, TPR: 0.00
# Threshold: 0.92, FPR: 0.00, TPR: 0.01
# Threshold: 0.88, FPR: 0.00, TPR: 0.01
# Threshold: 0.61, FPR: 0.00, TPR: 0.04
# Threshold: 0.60, FPR: 0.00, TPR: 0.04
# Threshold: 0.56, FPR: 0.00, TPR: 0.06
# Threshold: 0.55, FPR: 0.01, TPR: 0.06
# Threshold: 0.54, FPR: 0.01, TPR: 0.07
# Threshold: 0.49, FPR: 0.01, TPR: 0.07
# Threshold: 0.48, FPR: 0.01, TPR: 0.08
# Threshold: 0.48, FPR: 0.01, TPR: 0.08
# Threshold: 0.48, FPR: 0.01, TPR: 0.09
# Threshold: 0.47, FPR: 0.02, TPR: 0.09
# Threshold: 0.47, FPR: 0.02, TPR: 0.10
# Threshold: 0.45, FPR: 0.02, TPR: 0.10
# Threshold: 0.45, FPR: 0.02, TPR: 0.10
# Threshold: 0.44, FPR: 0.02, TPR: 0.10
# Threshold: 0.43, FPR: 0.02, TPR: 0.11
# Threshold: 0.42, FPR: 0.02, TPR: 0.11
# Threshold: 0.42, FPR: 0.02, TPR: 0.12
# Threshold: 0.41, FPR: 0.02, TPR: 0.12
# Threshold: 0.40, FPR: 0.02, TPR: 0.13
# Threshold: 0.40, FPR: 0.03, TPR: 0.13
# Threshold: 0.40, FPR: 0.03, TPR: 0.14
# Threshold: 0.40, FPR: 0.03, TPR: 0.14
# Threshold: 0.40, FPR: 0.03, TPR: 0.15
# Threshold: 0.37, FPR: 0.05, TPR: 0.15
# Threshold: 0.37, FPR: 0.05, TPR: 0.15
# Threshold: 0.36, FPR: 0.05, TPR: 0.15
# Threshold: 0.36, FPR: 0.05, TPR: 0.16
# Threshold: 0.36, FPR: 0.05, TPR: 0.16
# Threshold: 0.36, FPR: 0.05, TPR: 0.17
# Threshold: 0.36, FPR: 0.05, TPR: 0.17
# Threshold: 0.36, FPR: 0.05, TPR: 0.18
# Threshold: 0.34, FPR: 0.06, TPR: 0.18
# Threshold: 0.34, FPR: 0.06, TPR: 0.20
# Threshold: 0.33, FPR: 0.07, TPR: 0.20
# Threshold: 0.33, FPR: 0.07, TPR: 0.22
# Threshold: 0.32, FPR: 0.08, TPR: 0.22
# Threshold: 0.32, FPR: 0.08, TPR: 0.23
# Threshold: 0.32, FPR: 0.08, TPR: 0.23
# Threshold: 0.32, FPR: 0.08, TPR: 0.24
# Threshold: 0.32, FPR: 0.08, TPR: 0.24
# Threshold: 0.32, FPR: 0.08, TPR: 0.25
# Threshold: 0.31, FPR: 0.09, TPR: 0.25
# Threshold: 0.31, FPR: 0.09, TPR: 0.26
# Threshold: 0.30, FPR: 0.09, TPR: 0.26
# Threshold: 0.30, FPR: 0.09, TPR: 0.27
# Threshold: 0.29, FPR: 0.10, TPR: 0.27
# Threshold: 0.29, FPR: 0.10, TPR: 0.29
# Threshold: 0.28, FPR: 0.11, TPR: 0.29
# Threshold: 0.28, FPR: 0.11, TPR: 0.31
# Threshold: 0.28, FPR: 0.11, TPR: 0.31
# Threshold: 0.28, FPR: 0.11, TPR: 0.31
# Threshold: 0.28, FPR: 0.12, TPR: 0.31
# Threshold: 0.28, FPR: 0.12, TPR: 0.32
# Threshold: 0.27, FPR: 0.12, TPR: 0.32
# Threshold: 0.27, FPR: 0.12, TPR: 0.33
# Threshold: 0.26, FPR: 0.13, TPR: 0.33
# Threshold: 0.26, FPR: 0.13, TPR: 0.34
# Threshold: 0.26, FPR: 0.14, TPR: 0.34
# Threshold: 0.25, FPR: 0.14, TPR: 0.35
# Threshold: 0.25, FPR: 0.14, TPR: 0.35
# Threshold: 0.25, FPR: 0.14, TPR: 0.36
# Threshold: 0.25, FPR: 0.15, TPR: 0.36
# Threshold: 0.25, FPR: 0.15, TPR: 0.38
# Threshold: 0.24, FPR: 0.15, TPR: 0.38
# Threshold: 0.24, FPR: 0.15, TPR: 0.39
# Threshold: 0.24, FPR: 0.16, TPR: 0.39
# Threshold: 0.24, FPR: 0.16, TPR: 0.40
# Threshold: 0.24, FPR: 0.16, TPR: 0.40
# Threshold: 0.24, FPR: 0.16, TPR: 0.40
# Threshold: 0.24, FPR: 0.17, TPR: 0.40
# Threshold: 0.24, FPR: 0.17, TPR: 0.41
# Threshold: 0.23, FPR: 0.17, TPR: 0.41
# Threshold: 0.23, FPR: 0.17, TPR: 0.42
# Threshold: 0.23, FPR: 0.17, TPR: 0.42
# Threshold: 0.23, FPR: 0.17, TPR: 0.46
# Threshold: 0.23, FPR: 0.18, TPR: 0.46
# Threshold: 0.23, FPR: 0.18, TPR: 0.47
# Threshold: 0.22, FPR: 0.18, TPR: 0.47
# Threshold: 0.22, FPR: 0.18, TPR: 0.48
# Threshold: 0.22, FPR: 0.18, TPR: 0.48
# Threshold: 0.22, FPR: 0.18, TPR: 0.48
# Threshold: 0.22, FPR: 0.19, TPR: 0.48
# Threshold: 0.21, FPR: 0.19, TPR: 0.49
# Threshold: 0.21, FPR: 0.19, TPR: 0.49
# Threshold: 0.21, FPR: 0.19, TPR: 0.50
# Threshold: 0.21, FPR: 0.20, TPR: 0.50
# Threshold: 0.21, FPR: 0.20, TPR: 0.51
# Threshold: 0.20, FPR: 0.21, TPR: 0.51
# Threshold: 0.20, FPR: 0.21, TPR: 0.52
# Threshold: 0.19, FPR: 0.23, TPR: 0.52
# Threshold: 0.19, FPR: 0.23, TPR: 0.54
# Threshold: 0.18, FPR: 0.25, TPR: 0.54
# Threshold: 0.18, FPR: 0.25, TPR: 0.55
# Threshold: 0.18, FPR: 0.26, TPR: 0.55
# Threshold: 0.18, FPR: 0.26, TPR: 0.56
# Threshold: 0.17, FPR: 0.29, TPR: 0.56
# Threshold: 0.17, FPR: 0.29, TPR: 0.56
# Threshold: 0.17, FPR: 0.30, TPR: 0.56
# Threshold: 0.17, FPR: 0.30, TPR: 0.57
# Threshold: 0.17, FPR: 0.30, TPR: 0.57
# Threshold: 0.17, FPR: 0.30, TPR: 0.58
# Threshold: 0.17, FPR: 0.31, TPR: 0.58
# Threshold: 0.17, FPR: 0.31, TPR: 0.59
# Threshold: 0.17, FPR: 0.31, TPR: 0.59
# Threshold: 0.17, FPR: 0.31, TPR: 0.60
# Threshold: 0.16, FPR: 0.32, TPR: 0.60
# Threshold: 0.16, FPR: 0.32, TPR: 0.60
# Threshold: 0.16, FPR: 0.32, TPR: 0.60
# Threshold: 0.16, FPR: 0.32, TPR: 0.62
# Threshold: 0.16, FPR: 0.32, TPR: 0.62
# Threshold: 0.16, FPR: 0.32, TPR: 0.63
# Threshold: 0.16, FPR: 0.33, TPR: 0.63
# Threshold: 0.16, FPR: 0.33, TPR: 0.64
# Threshold: 0.16, FPR: 0.33, TPR: 0.64
# Threshold: 0.16, FPR: 0.33, TPR: 0.65
# Threshold: 0.16, FPR: 0.34, TPR: 0.65
# Threshold: 0.16, FPR: 0.34, TPR: 0.66
# Threshold: 0.15, FPR: 0.35, TPR: 0.66
# Threshold: 0.15, FPR: 0.35, TPR: 0.67
# Threshold: 0.15, FPR: 0.37, TPR: 0.67
# Threshold: 0.15, FPR: 0.37, TPR: 0.68
# Threshold: 0.15, FPR: 0.37, TPR: 0.68
# Threshold: 0.15, FPR: 0.37, TPR: 0.69
# Threshold: 0.14, FPR: 0.39, TPR: 0.69
# Threshold: 0.14, FPR: 0.39, TPR: 0.69
# Threshold: 0.14, FPR: 0.39, TPR: 0.69
# Threshold: 0.14, FPR: 0.39, TPR: 0.70
# Threshold: 0.14, FPR: 0.41, TPR: 0.70
# Threshold: 0.14, FPR: 0.41, TPR: 0.71
# Threshold: 0.13, FPR: 0.42, TPR: 0.71
# Threshold: 0.13, FPR: 0.42, TPR: 0.72
# Threshold: 0.12, FPR: 0.48, TPR: 0.72
# Threshold: 0.12, FPR: 0.48, TPR: 0.73
# Threshold: 0.12, FPR: 0.49, TPR: 0.73
# Threshold: 0.12, FPR: 0.49, TPR: 0.73
# Threshold: 0.12, FPR: 0.49, TPR: 0.73
# Threshold: 0.12, FPR: 0.49, TPR: 0.74
# Threshold: 0.12, FPR: 0.49, TPR: 0.74
# Threshold: 0.12, FPR: 0.49, TPR: 0.75
# Threshold: 0.11, FPR: 0.50, TPR: 0.75
# Threshold: 0.11, FPR: 0.50, TPR: 0.76
# Threshold: 0.11, FPR: 0.50, TPR: 0.76
# Threshold: 0.11, FPR: 0.50, TPR: 0.77
# Threshold: 0.11, FPR: 0.50, TPR: 0.77
# Threshold: 0.11, FPR: 0.50, TPR: 0.77
# Threshold: 0.11, FPR: 0.51, TPR: 0.77
# Threshold: 0.11, FPR: 0.51, TPR: 0.78
# Threshold: 0.11, FPR: 0.53, TPR: 0.78
# Threshold: 0.11, FPR: 0.53, TPR: 0.79
# Threshold: 0.11, FPR: 0.54, TPR: 0.79
# Threshold: 0.10, FPR: 0.54, TPR: 0.80
# Threshold: 0.10, FPR: 0.54, TPR: 0.80
# Threshold: 0.10, FPR: 0.54, TPR: 0.81
# Threshold: 0.10, FPR: 0.55, TPR: 0.81
# Threshold: 0.10, FPR: 0.55, TPR: 0.81
# Threshold: 0.10, FPR: 0.56, TPR: 0.81
# Threshold: 0.10, FPR: 0.56, TPR: 0.82
# Threshold: 0.10, FPR: 0.56, TPR: 0.82
# Threshold: 0.10, FPR: 0.56, TPR: 0.83
# Threshold: 0.10, FPR: 0.57, TPR: 0.83
# Threshold: 0.10, FPR: 0.57, TPR: 0.84
# Threshold: 0.09, FPR: 0.59, TPR: 0.84
# Threshold: 0.09, FPR: 0.59, TPR: 0.85
# Threshold: 0.09, FPR: 0.59, TPR: 0.85
# Threshold: 0.09, FPR: 0.59, TPR: 0.85
# Threshold: 0.08, FPR: 0.64, TPR: 0.85
# Threshold: 0.08, FPR: 0.64, TPR: 0.86
# Threshold: 0.08, FPR: 0.64, TPR: 0.86
# Threshold: 0.08, FPR: 0.64, TPR: 0.88
# Threshold: 0.08, FPR: 0.64, TPR: 0.88
# Threshold: 0.08, FPR: 0.64, TPR: 0.89
# Threshold: 0.08, FPR: 0.67, TPR: 0.89
# Threshold: 0.08, FPR: 0.67, TPR: 0.90
# Threshold: 0.08, FPR: 0.68, TPR: 0.90
# Threshold: 0.08, FPR: 0.68, TPR: 0.90
# Threshold: 0.07, FPR: 0.69, TPR: 0.90
# Threshold: 0.07, FPR: 0.69, TPR: 0.91
# Threshold: 0.07, FPR: 0.72, TPR: 0.91
# Threshold: 0.07, FPR: 0.72, TPR: 0.92
# Threshold: 0.07, FPR: 0.73, TPR: 0.92
# Threshold: 0.07, FPR: 0.73, TPR: 0.93
# Threshold: 0.07, FPR: 0.73, TPR: 0.93
# Threshold: 0.07, FPR: 0.73, TPR: 0.94
# Threshold: 0.07, FPR: 0.74, TPR: 0.94
# Threshold: 0.07, FPR: 0.74, TPR: 0.95
# Threshold: 0.06, FPR: 0.79, TPR: 0.95
# Threshold: 0.06, FPR: 0.79, TPR: 0.96
# Threshold: 0.06, FPR: 0.80, TPR: 0.96
# Threshold: 0.06, FPR: 0.80, TPR: 0.97
# Threshold: 0.05, FPR: 0.81, TPR: 0.97
# Threshold: 0.05, FPR: 0.81, TPR: 0.98
# Threshold: 0.05, FPR: 0.82, TPR: 0.98
# Threshold: 0.05, FPR: 0.82, TPR: 0.98
# Threshold: 0.04, FPR: 0.88, TPR: 0.98
# Threshold: 0.04, FPR: 0.88, TPR: 1.00
# Threshold: 0.02, FPR: 1.00, TPR: 1.00

# %%
import matplotlib.pyplot as plt

plt.plot(fpr, tpr,label="ROC Curve (AUC = {:.2f})".format(auc))
plt.plot([0, 1], [0, 1], linestyle='--', label="Random Classifier")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("ROC Curve with Thresholds")

threshold_idx = [0, len(thresholds) // 2, -1]  # start, middle, end
for idx in threshold_idx:
    plt.annotate(f"{thresholds[idx]:.2f}", (fpr[idx], tpr[idx]), textcoords="offset points", xytext=(10,-10))

plt.legend()
plt.show()

# %%
y_prob = LR_model.predict_proba(X_test)[:, 1]  # Only need probabilities for the positive class
threshold = 0.17
y_pred_custom = (y_prob >= threshold).astype(int)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred_custom)
precision = precision_score(y_test, y_pred_custom)
recall = recall_score(y_test, y_pred_custom)
f1 = f1_score(y_test, y_pred_custom)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.6816037735849056
# Precision: 0.2465277777777778
# Recall: 0.5725806451612904
# F1 Score: 0.3446601941747573

# %%
print(classification_report(y_test , y_pred_custom))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.70      0.79       724
#            1       0.25      0.57      0.34       124
#
#     accuracy                           0.68       848
#    macro avg       0.58      0.64      0.57       848
# weighted avg       0.81      0.68      0.72       848

# %%
import joblib

# Assuming your pipeline is stored in LR_model
pickle.dump(LR_model,open('model_LogisticRegression.pkl','wb'))
